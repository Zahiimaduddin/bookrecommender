# %%
import pandas as pd

# %%
df = pd.read_csv('books.csv')

# %%
df
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
def textual_representation(row):
    textual_representation = f"""Title: {row['title']}
Authors: {row['authors']}
Description: {row['description']}
Categories: {row['categories']}
Published Year: {row['published_year']}
Average Rating: {row['average_rating']}
Number of Pages: {row['num_pages']}
""" 

    return textual_representation

    # f string lets us put stuff in the string
    # tripple quotation means the string saves the line breaks
    # So basically for each horizontal entry, this function takes all the data and formats it into one
    # multi-line string

# %%
print(df.iloc[:5].apply(textual_representation, axis=1).values[0])
# Out:
# Title: Gilead
# Authors: Marilynne Robinson
# ...

# %%
# This creates a new column in the data frame, then populates it with the string
# we formatted above
df['textual_representation'] = df.apply(textual_representation, axis=1)

# %%
df # just showing the updated dataframe
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
# Just an example that there really is the whole string here
print(df.iloc[1,12])
# Out:
# Title: Spider's Web
# Authors: Charles Osborne;Agatha Christie
# ...

# %%
import faiss
import requests 
import numpy as np

# this is the dimensionality we feed to faiss because its the same as the llama2 embedding model
dim = 4096

# Explain this
Index = faiss.IndexFlatL2(dim)

# Explain this
X = np.zeros((len(df['textual_representation']), dim), dtype='float32')

# %%
for i, representation in enumerate(df['textual_representation']):
    print(i)

    # if i % 100 == 0:
      #  print(i)
    
    res = requests.post('http://localhost:11434/api/embeddings',
                      json = {
                          'model': 'llama2',
                          'prompt': representation
                      })

    print ("Request Done")
    embedding  = res.json()['embedding']
    print ("Stored as embedding Done")

    X[i] = np.array(embedding)

Index.add(X)
# Out:
# 0
# Request Done
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 14
#       7 res = requests.post('http://localhost:11434/api/embeddings',
#       8                   json = {
#       9                       'model': 'llama2',
#      10                       'prompt': representation
#      11                   })
#      13 print ("Request Done")
# ---> 14 embedding  = res.json()['embedding']
#      15 print ("Stored as embedding Done")
#      17 X[i] = np.array(embedding)
#
# KeyError: 'embedding'

# %%
faiss.write(index, 'index')

# %%
index = faiss.read_index('index')

# %%
df[df.title.str.contains('Friends')]

# %%
favorite_book = df.iloc[4533]

# %%
print(favorite_book['textual_representation'])

# %%
# To search the DB for something similar to a string you craft
# 1. craft the string 
# 2. embed it 
# 3. preform similarity search

res = requests.post('http://localhost:11434/api/embeddings',
                    json = {
                        'model': 'llama2',
                        'prompt': representation
                    })

# %%
embedding = np.array([res.json()['embedding']], dtype='float32')

# %%
D, I = index.search(embedding, 5)

# %%
best_matches = np.array(df['textual_representation'])[I.flatten()]

# %%
for match in best_matches:
    print(match)
    print()
